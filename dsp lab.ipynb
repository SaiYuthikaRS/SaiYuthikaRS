# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiYuthikaRS/SaiYuthikaRS/blob/main/dsp%20lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# gratings.py

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 100
angle = np.pi/9
grating = np.sin(
    2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength
)

plt.set_cmap("gray")

plt.subplot(131)
plt.imshow(grating)
plt.axis("off")

# Calculate the Fourier transform of the grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(132)
plt.imshow(abs(ft))
plt.axis("off")
plt.xlim([480, 520])
plt.ylim([520, 480])

# Calculate the inverse Fourier transform of
# the Fourier transform
ift = np.fft.ifftshift(ft)
ift = np.fft.ifft2(ift)
ift = np.fft.fftshift(ift)
ift = ift.real  # Take only the real part

plt.subplot(133)
plt.imshow(ift)
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Load the Lenna image
try:
    # Replace "lenna.png" with the actual path to your image file if it's not in the same directory
    lenna = imread("lenna.png")
except FileNotFoundError:
    print("Error: lenna.png not found. Make sure the image is in the correct directory or provide the full path.")
    # Download the image if it is not found
    # !wget https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png -O lenna.png
    lenna = imread("lenna.png")

plt.set_cmap("gray")  # You can change the colormap if needed

plt.subplot(131)
plt.imshow(lenna)
plt.title("Original Lenna")
plt.axis("off")

# Calculate the Fourier transform of the Lenna image
ft_lenna = np.fft.ifftshift(lenna)
ft_lenna = np.fft.fft2(ft_lenna)
ft_lenna = np.fft.fftshift(ft_lenna)

plt.subplot(132)
plt.imshow(np.log(np.abs(ft_lenna) + 1))  # Display the magnitude in log scale for better visualization
plt.title("Fourier Transform")
plt.axis("off")

# Calculate the inverse Fourier transform
ift_lenna = np.fft.ifftshift(ft_lenna)
ift_lenna = np.fft.ifft2(ift_lenna)
ift_lenna = np.fft.fftshift(ift_lenna)
ift_lenna = np.abs(ift_lenna)  # Take the absolute value for display

plt.subplot(133)
plt.imshow(ift_lenna)
plt.title("Inverse Fourier Transform")
plt.axis("off")

plt.tight_layout() # Adjust subplot parameters for a tight layout.
plt.show()
# Out:
# Error: lenna.png not found. Make sure the image is in the correct directory or provide the full path.
# --2025-04-28 11:31:00--  https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘lenna.png’
#
# lenna.png           100%[===================>] 462.73K  --.-KB/s    in 0.1s
#
# 2025-04-28 11:31:00 (3.77 MB/s) - ‘lenna.png’ saved [473831/473831]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.3841855e-07..6.8033876].
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)
X, Y = np.meshgrid(x, x)
wavelength = 100
angle = np.pi / 9
grating = np.sin(2 * np.pi * (X * np.cos(angle) + Y * np.sin(angle)) / wavelength)

plt.set_cmap("gray")

plt.subplot(141)
plt.imshow(grating)
plt.title("Original Grating")
plt.axis("off")

# Calculate the Fourier transform of the grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(142)
plt.imshow(np.abs(ft))
plt.title("Magnitude Spectrum")
plt.axis("off")
plt.xlim([480, 520])
plt.ylim([520, 480])

# Calculate the phase spectrum
phase_spectrum = np.angle(ft)

plt.subplot(143)
plt.imshow(phase_spectrum, cmap='viridis')  # Use a different colormap for phase
plt.title("Phase Spectrum")
plt.axis("off")
plt.colorbar(label='Phase (radians)')

# Calculate the inverse Fourier transform
ift = np.fft.ifftshift(ft)
ift = np.fft.ifft2(ift)
ift = np.fft.fftshift(ift)
ift = ift.real  # Take only the real part

plt.subplot(144)
plt.imshow(ift)
plt.title("Inverse Transform")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Load the Lenna image
try:
    # Replace "lenna.png" with the actual path to your image file if it's not in the same directory
    lenna = imread("lenna.png")
except FileNotFoundError:
    print("Error: lenna.png not found. Make sure the image is in the correct directory or provide the full path.")
    # Download the image if it is not found
    import os
    if not os.path.exists("lenna.png"):
        print("Downloading lenna.png...")
        try:
            import urllib.request
            urllib.request.urlretrieve("https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png", "lenna.png")
            lenna = imread("lenna.png")
        except Exception as e:
            print(f"Error downloading image: {e}")
            exit()
    else:
        lenna = imread("lenna.png")

plt.set_cmap("gray")  # You can change the colormap if needed

plt.subplot(141)
plt.imshow(lenna)
plt.title("Original Lenna")
plt.axis("off")

# Calculate the Fourier transform of the Lenna image
ft_lenna = np.fft.ifftshift(lenna)
ft_lenna = np.fft.fft2(ft_lenna)
ft_lenna = np.fft.fftshift(ft_lenna)

plt.subplot(142)
plt.imshow(np.log(np.abs(ft_lenna) + 1), cmap='gray')  # Display the magnitude in log scale for better visualization
plt.title("Magnitude Spectrum")
plt.axis("off")

# Calculate the phase spectrum
phase_spectrum = np.angle(ft_lenna)

plt.subplot(143)
plt.imshow(phase_spectrum, cmap='viridis')  # Use a different colormap for phase
plt.title("Phase Spectrum")
plt.axis("off")
plt.colorbar(label='Phase (radians)')

# Calculate the inverse Fourier transform
ift_lenna = np.fft.ifftshift(ft_lenna)
ift_lenna = np.fft.ifft2(ift_lenna)
ift_lenna = np.fft.fftshift(ift_lenna)
ift_lenna = np.abs(ift_lenna)  # Take the absolute value for display

plt.subplot(144)
plt.imshow(ift_lenna, cmap='gray')
plt.title("Inverse Transform")
plt.axis("off")

plt.tight_layout() # Adjust subplot parameters for a tight layout.
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.3841855e-07..6.8033876].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-3.1415925..3.1415927].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0117646605..1.0000002].
